# %%
import torch
import matplotlib.pyplot as plt
[scrappie, real, fake_scrappie, fake_real] = torch.load('./signals_result/signals_GAN_test.pt')

# %%
scrappie.shape
print(real.shape)
print(fake_scrappie.shape)
print(fake_real.shape)
# Out:
# torch.Size([1, 1, 152])
# torch.Size([1, 1, 152])
# torch.Size([1, 1, 152])

# %%
plt.plot(scrappie[0][0].cpu(), label='scrappie')
plt.plot(fake_real[0][0].cpu(), label='fake_real_signal')
plt.legend()

# %%
plt.plot(real[0][0].cpu())
plt.plot(fake_scrappie[0][0].cpu())
